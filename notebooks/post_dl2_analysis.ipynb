# %% [markdown]
# # Fast Analaysis LST Plots

# %% [markdown]
# ### Setup notebook appearance

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Run example wobble analysis

# %%
from lstchain.analysis.post_dl2 import LOGGER, setup_logging
from lstchain.scripts.lstchain_post_dl2 import run
setup_logging(2)
run('/home/mykhailo.dalchenko/code/cta-lstchain/docs/examples/post_dl2_analysis/config_wobble.toml')
# Out:
# /home/mykhailo.dalchenko/venv-python3/lib/python3.7/site-packages/ctapipe/tools/stage1.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# 2020-12-11 14:17:45,764 - post_dl2 - INFO - Loaded configuration:
# [input]
# data_tag = "v0.5.1_v03"
# observed_source = "Mrk 421"
# columns_to_read = [ "alt_tel", "az_tel", "dragon_time", "gammaness", "intensity", "leakage2_intensity", "n_pixels", "reco_src_x", "reco_src_y", "wl",]
#
# [output]
# interactive = true
# directory = "/tmp"
#
# [preselection]
# intensity = [ 100, 1000000,]
# leakage2_intensity = [ 0.0, 0.1,]
# wl = [ 0.0, 1.0,]
# gammaness = [ 0.8, 1.0,]
# n_pixels = [ 0, 1800,]
#
# [analysis]
# type = "wobble"
# runs = [ 2130, 2131, 2132, 2133,]
#
# [analysis.parameters]
# n_points = 4
#
# [analysis.selection]
# theta2 = [ 0.1, 0.5, 2.0,]
#
# [plot_style.figure]
# figsize = 12
#
# [plot_style.font]
# size = 20
#
# 2020-12-11 14:17:45,825 - post_dl2 - INFO - Running wobble analysis with 4 off-source observation points
# 2020-12-11 14:17:45,826 - post_dl2 - INFO - Analyzing runs [2130, 2131, 2132, 2133]
# 2020-12-11 14:18:04,139 - post_dl2 - DEBUG -
# Preselection:
# {'intensity': [100, 1000000], 'leakage2_intensity': [0.0, 0.1], 'wl': [0.0, 1.0], 'gammaness': [0.8, 1.0], 'n_pixels': [0, 1800]}
# 2020-12-11 14:18:04,143 - post_dl2 - DEBUG -
# Parameter: intensity, range: [100, 1000000], value type: <class 'list'>
# 2020-12-11 14:18:04,144 - post_dl2 - DEBUG -
# Parameter: leakage2_intensity, range: [0.0, 0.1], value type: <class 'list'>
# 2020-12-11 14:18:04,145 - post_dl2 - DEBUG -
# Parameter: wl, range: [0.0, 1.0], value type: <class 'list'>
# 2020-12-11 14:18:04,146 - post_dl2 - DEBUG -
# Parameter: gammaness, range: [0.8, 1.0], value type: <class 'list'>
# 2020-12-11 14:18:04,147 - post_dl2 - DEBUG -
# Parameter: n_pixels, range: [0, 1800], value type: <class 'list'>
# 2020-12-11 14:18:16,574 - post_dl2 - INFO - Observation time 3546.7684533299957
# 2020-12-11 14:18:16,577 - post_dl2 - INFO - Number of "ON" events 775
# 2020-12-11 14:18:16,579 - post_dl2 - INFO - Number of "OFF" events 854
# 2020-12-11 14:18:16,580 - post_dl2 - INFO - ON/OFF observation time ratio 0.3333333333333333
# 2020-12-11 14:18:16,581 - post_dl2 - INFO - Excess is 490.33333333333337
# 2020-12-11 14:18:16,582 - post_dl2 - INFO - Li&Ma significance 19.638645909190767
# 2020-12-11 14:18:17,002 - post_dl2 - INFO - Interactive mode ON, plots will be only shown, but not saved

# %% [markdown]
# ### Run example on/off analysis

# %%
run('/home/mykhailo.dalchenko/code/cta-lstchain/docs/examples/post_dl2_analysis/config_on_off.toml')
# Out:
# 2020-12-11 14:18:18,930 - post_dl2 - INFO - Loaded configuration:
# [input]
# data_tag = "v0.5.1_v03"
# columns_to_read = [ "alt_tel", "az_tel", "dragon_time", "gammaness", "intensity", "leakage2_intensity", "n_pixels", "phi", "psi", "reco_src_x", "reco_src_y", "wl",]
#
# [output]
# interactive = false
# directory = "/tmp"
#
# [preselection]
# intensity = [ 300, 1000000,]
# leakage2_intensity = [ 0.0, 0.2,]
# wl = [ 0.01, 1.0,]
# gammaness = [ 0.9, 1.0,]
# n_pixels = [ 0, 2000,]
#
# [analysis]
# type = "on_off"
# runs_on = [ 1874, 1875, 1876, 1878, 1879, 1880,]
# runs_off = [ 1877, 1881,]
#
# [analysis.parameters]
# n_points = 4
#
# [analysis.selection]
# theta2 = [ 0.075, 0.5, 2.0,]
# alpha = [ 5.0, 20.0, 80.0,]
#
# [plot_style.figure]
# figsize = 12
#
# [plot_style.font]
# size = 20
#
# 2020-12-11 14:18:18,967 - post_dl2 - INFO - Running ON/OFF analysis
# 2020-12-11 14:18:18,968 - post_dl2 - INFO - ON data runs: [1874, 1875, 1876, 1878, 1879, 1880]
# 2020-12-11 14:19:05,942 - post_dl2 - INFO - ON observation time: 6407.8668959089955
# 2020-12-11 14:19:05,944 - post_dl2 - INFO - OFF data runs: [1877, 1881]
# 2020-12-11 14:19:23,565 - post_dl2 - INFO - OFF observation time: 2426.285903691999
# 2020-12-11 14:19:32,152 - post_dl2 - INFO - Number of observed ON and OFF events are:
#  508, 25
# 2020-12-11 14:19:32,154 - post_dl2 - INFO - Excess is 439.3169164882227
# 2020-12-11 14:19:32,155 - post_dl2 - INFO - Excess significance is 13.40307919187028
# 2020-12-11 14:19:32,288 - post_dl2 - INFO - Perform alpha analysis
# 2020-12-11 14:19:34,140 - post_dl2 - INFO - Number of observed ON and OFFevents are:
#  767, 147
# 2020-12-11 14:19:34,142 - post_dl2 - INFO - Excess is 377.5509761388286
# 2020-12-11 14:19:34,144 - post_dl2 - INFO - Excess significance is 8.099879859890942
# 2020-12-11 14:19:34,303 - post_dl2 - INFO - Interactive mode OFF, no plots will be displayed
