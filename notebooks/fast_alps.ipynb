# %% [markdown]
# # Fast Analaysis LST Plots

# %% [markdown]
# ### Setup notebook appearance

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Run example wobble analysis

# %%
from lstchain.analysis.fast_alps import LOGGER, setup_logging
from lstchain.scripts.lstchain_fast_alps import run
setup_logging(2)
run('/home/mykhailo.dalchenko/code/cta-lstchain/docs/examples/fast_alps/config_wobble.toml')
# Out:
# /home/mykhailo.dalchenko/venv-python3/lib/python3.7/site-packages/ctapipe/tools/stage1.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# 2020-09-02 16:33:39,432 - fast_alps - INFO - Loaded configuration:
# [input]
# data_path = "/fefs/aswg/data/real/DL2/20200622/v0.5.1_v03/"
# observed_source = "Mrk 421"
# columns_to_read = [ "alt_tel", "az_tel", "dragon_time", "gammaness", "intensity", "leakage2_intensity", "n_pixels", "reco_src_x", "reco_src_y", "wl",]
#
# [preselection]
# intensity = [ 100, 1000000,]
# leakage2_intensity = [ 0.0, 0.1,]
# wl = [ 0.0, 1.0,]
# gammaness = [ 0.8, 1.0,]
# n_pixels = [ 0, 1800,]
#
# [analysis]
# type = "wobble"
# runs = [ 2130, 2131, 2132, 2133,]
#
# [analysis.parameters]
# n_points = 4
#
# [analysis.selection]
# theta2 = [ 0.1, 0.5, 2.0,]
#
# [plot_style.figure]
# figsize = 12
#
# [plot_style.font]
# size = 20
# ...

# %% [markdown]
# ### Run example on/off analysis

# %%
run('/home/mykhailo.dalchenko/code/cta-lstchain/docs/examples/fast_alps/config_on_off.toml')
# Out:
# 2020-09-02 16:34:12,501 - fast_alps - INFO - Loaded configuration:
# [input]
# data_path = "/fefs/aswg/data/real/DL2/20200127/v0.5.1_v03/"
# columns_to_read = [ "alt_tel", "az_tel", "dragon_time", "gammaness", "intensity", "leakage2_intensity", "n_pixels", "phi", "psi", "reco_src_x", "reco_src_y", "wl",]
#
# [preselection]
# intensity = [ 300, 1000000,]
# leakage2_intensity = [ 0.0, 0.2,]
# wl = [ 0.01, 1.0,]
# gammaness = [ 0.9, 1.0,]
# n_pixels = [ 0, 2000,]
#
# [analysis]
# type = "on_off"
# runs_on = [ 1874, 1875, 1876, 1878, 1879, 1880,]
# runs_off = [ 1877, 1881,]
#
# [analysis.parameters]
# n_points = 4
#
# [analysis.selection]
# theta2 = [ 0.075, 0.5, 2.0,]
# alpha = [ 5.0, 20.0, 80.0,]
#
# [plot_style.figure]
# figsize = 12
#
# [plot_style.font]
# size = 20
#
# 2020-09-02 16:34:12,537 - fast_alps - INFO - Running ON/OFF analysis
# 2020-09-02 16:34:12,538 - fast_alps - INFO - ON data runs: [1874, 1875, 1876, 1878, 1879, 1880]
# ...
