# %% [markdown]
# # Data exploration and visusalisation with pandas
# This is an example notebook to show how to use pandas for quick data exploration and results visualition based on a results hdf5 file.

# %% [markdown]
# ## Imports and data download for cta-lstchain-extra

# %%
import os
if not 'gamma_events_point_tiny.h5' in os.listdir('.'):
    # !wget https://github.com/cta-observatory/cta-lstchain-extra/raw/master/reco/sample_data/dl1/gamma_events_point_tiny.h5
if not 'proton_events_tiny.h5' in os.listdir('.'):
    # !wget https://github.com/cta-observatory/cta-lstchain-extra/raw/master/reco/sample_data/dl1/proton_events_tiny.h5
        
# !ls gamma_events_point_tiny.h5
# !ls proton_events_tiny.h5
# Out:
# /bin/sh: wget: command not found
# /bin/sh: wget: command not found
# ls: gamma_events_point_tiny.h5: No such file or directory
# ls: proton_events_tiny.h5: No such file or directory

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
# Out:
# <style>.container { width:98% !important; }</style>

# %%
gammas_table = pd.read_hdf('gamma_events_point_tiny.h5')
protons_table = pd.read_hdf('proton_events_tiny.h5')

# %%
gammas_table.describe()
# Out:
#              obs_id      event_id     mc_energy       mc_alt         mc_az  \
# count  53386.000000  5.338600e+04  53386.000000  53386.00000  53386.000000
# mean   11027.225621  5.005307e+06      1.942175      1.22173      6.283185
# std      657.878752  2.881663e+06      0.618715      0.00000      0.000000
# min    10147.000000  1.060000e+02      0.488904      1.22173      6.283185
# 25%    10385.000000  2.500426e+06      1.495644      1.22173      6.283185
# 50%    11495.000000  5.020252e+06      1.834652      1.22173      6.283185
# 75%    11681.000000  7.505481e+06      2.286065      1.22173      6.283185
# max    11715.000000  9.999901e+06      5.498749      1.22173      6.283185
#
#           mc_core_x     mc_core_y  mc_h_first_int  mc_type      gps_time  \
# count  53386.000000  53386.000000    53386.000000  53386.0  5.338600e+04
# mean     -85.030647     -6.025231    24381.323851      0.0  1.445304e+09
# std      144.385035    185.809033     8190.777433      0.0  1.219079e+05
# min    -1077.981934  -1498.965942     6754.455566      0.0  1.445077e+09
# 25%     -186.122799   -132.039860    18699.628906      0.0  1.445190e+09
# 50%      -83.920982     -5.786307    22871.404297      0.0  1.445334e+09
# 75%       15.989897    119.391779    28295.680176      0.0  1.445410e+09
# max      707.513733   1480.202148    94513.046875      0.0  1.445554e+09
#
#          ...       mc_alt_tel  mc_az_tel        impact      mc_x_max  \
# count    ...      53386.00000    53386.0  53386.000000  53386.000000
# mean     ...          1.22173        0.0    209.228140    243.016315
# std      ...          0.00000        0.0    108.722932     69.255351
# min      ...          1.22173        0.0      1.251538    -20.000000
# 25%      ...          1.22173        0.0    129.576214    195.714279
# 50%      ...          1.22173        0.0    194.657316    236.666672
# 75%      ...          1.22173        0.0    275.212832    282.110817
# max      ...          1.22173        0.0   1504.107425    775.039368
#
#        time_gradient     intercept         src_x         src_y          disp  \
# count   5.338600e+04  53386.000000  5.338600e+04  5.338600e+04  53386.000000
# mean   -2.499263e-02      7.501868  4.103384e-13 -2.892042e-06      0.512015
# std     3.498411e+01     13.831399  1.514627e-28  8.470409e-22      0.256083
# min    -1.454972e+03  -1178.036708  4.103384e-13 -2.892042e-06      0.002000
# 25%    -1.078555e+01      5.024158  4.103384e-13 -2.892042e-06      0.308793
# 50%    -2.128057e-15      8.478582  4.103384e-13 -2.892042e-06      0.474126
# 75%     1.087460e+01     10.539176  4.103384e-13 -2.892042e-06      0.706576
# max     1.185533e+03    574.001388  4.103384e-13 -2.892042e-06      1.157268
#
#        hadroness
# count    53386.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
#
# [8 rows x 31 columns]

# %%
protons_table.describe()
# Out:
#               ObsID          EvID      mcEnergy         mcAlt          mcAz  \
# count  21955.000000  2.195500e+04  21955.000000  21955.000000  21955.000000
# mean   10029.136142  1.249777e+07      2.911563      1.219757      2.807571
# std       17.401747  7.219733e+06      0.859592      0.042087      3.022722
# min    10000.000000  1.511000e+03      0.871235      1.051407      0.000011
# 25%    10014.000000  6.213855e+06      2.286663      1.194721      0.075133
# 50%    10029.000000  1.245881e+07      2.770276      1.219714      0.220030
# 75%    10044.000000  1.875246e+07      3.409291      1.245218      6.196048
# max    10060.000000  2.499960e+07      5.771707      1.387154      6.283185
#
#            mcCore_x      mcCore_y      mcHfirst   mcType       GPStime  \
# count  21955.000000  21955.000000  21955.000000  21955.0  2.195500e+04
# mean     -84.989301    -13.068417  21552.201344    101.0  1.445182e+09
# std      393.440873    389.140402   8368.280433      0.0  5.887602e+04
# min    -2314.490234  -2078.167969   1845.921143    101.0  1.445077e+09
# 25%     -297.265823   -230.817223  15894.279785    101.0  1.445132e+09
# 50%      -82.872803    -15.543711  19918.113281    101.0  1.445183e+09
# 75%      129.689308    205.341873  25383.309570    101.0  1.445235e+09
# max     2151.313965   2058.821777  81508.960938    101.0  1.445298e+09
#
#            ...       mcAztel        impact        mcXmax  time_gradient  \
# count      ...       21955.0  21955.000000  21955.000000   2.195500e+04
# mean       ...           0.0    451.542572    310.673737   1.530562e-01
# std        ...           0.0    320.286237    118.058154   3.399950e+01
# min        ...           0.0      3.476859    -20.000000  -6.965798e+02
# 25%        ...           0.0    227.895540    225.000000  -1.075313e+01
# 50%        ...           0.0    376.165305    296.067413   3.963823e-15
# 75%        ...           0.0    583.084333    378.000000   1.081985e+01
# max        ...           0.0   2319.129466   1230.000000   7.005423e+02
#
#           intercept          SrcX          SrcY          disp  hadroness  \
# count  21955.000000  21955.000000  21955.000000  21955.000000    21955.0
# mean      11.344205      0.023816      0.136649      1.232332        1.0
# std       19.357361      1.188733      1.260619      0.898988        0.0
# min     -465.554390     -4.780236     -4.912495      0.001904        1.0
# 25%        7.002148     -0.695184     -0.626704      0.588818        1.0
# 50%       10.479771      0.009756      0.148933      0.969754        1.0
# 75%       15.505116      0.735001      0.894329      1.619771        1.0
# max      399.639874      4.729510      4.821137      5.437771        1.0
#
#                 w/l
# count  21955.000000
# mean       0.451040
# std        0.218470
# min        0.000000
# 25%        0.285872
# 50%        0.436070
# 75%        0.612810
# max        0.996741
#
# [8 rows x 31 columns]

# %%
hist_opt = {'figsize':(18,18), 'density':True, 'alpha':0.6, 'bins':80}
axes = gammas_table.hist(label='diffuse gammas', **hist_opt);
axes = protons_table.hist(ax=axes.ravel()[:len(gammas_table.columns)], label='protons', **hist_opt);

# %% [markdown]
# ## Correlation matrices

# %%
import seaborn as sns

# %%
# Gammas
f, ax = plt.subplots(figsize=(10, 8))
features = gammas_table.columns
corr = gammas_table[features].corr()
sns.heatmap(corr, 
            mask=np.zeros_like(corr, dtype=np.bool),
            cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, 
            ax=ax);

# %%
# Protons
f, ax = plt.subplots(figsize=(10, 8))
features = protons_table.columns
corr = protons_table[features].corr()
sns.heatmap(corr, 
            mask=np.zeros_like(corr, dtype=np.bool),
            cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, 
            ax=ax);
